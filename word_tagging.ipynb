# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./data/train.csv", sep='\t')

# %%
data
# Out:
#        row_id                                            content  \
# 0        9386                                       给妈妈买的，妈妈很满意。
# 1       12586  我觉得不是正品，牙刷的后面有个点非常粗糙，刮嘴唇，和原厂的差太远，之前用的刷头上写的是dia...
# 2        4849                                        是正品  好用[追评]
# 3        9712                                     手机声音还可以，电池不怎么样
# 4        8148                                         家人喜欢，好看，实用
# 5        8965  感觉被坑了&hellip;&hellip;被坑了&hellip;&hellip;被坑了&he...
# 6       11635                      没感觉这款手霜多么好抹啊。还不及我10块钱一支的屈臣氏好用
# 7       17002                                      味道不是很好，效果没多明显
# 8       15601                                  太薄了根本不是保暧内衣而是秋衣秋裤
# 9       15135  体验了半个月左右，感觉不错，支撑力挺好的，不知是否和体重有关，但这床垫沒有之前购买乳胶枕的味...
# 10      14642                                        活动时购买的，还可以吧
# 11      14917  这是Rain Design mStand的山寨产品，百度一下，一看设计雅俗立分，明显是糊弄没...
# 12      15613                           没赶上特价，但有需求，就拍了。感觉头变大了不少。
# 13       9743          每次一不小心揉眼睛眼睛就痒的不行，最薰衣草款最精确的形容就是兰州拉面味儿，标准的。
# 14       6155                                            老年人用挺合适
# 15      14357                                        这膜两侧会起翘，贴不牢
# 16      10307                            是第二次购买了，发很货快，当天收到就安排装好了
# 17      12053                                      还没有开始用，先给个好评。
# 18      11643  样子还可以，价格太高，关键是不值，让我怀疑这是真的富光杯吗？实际测试，室温21度，刚烧开的水...
# 19      12810  收到货的时候，那时候因为父亲过世，没有心情去验货。现在用过之后发现喷雾那项是坏的，卖家如果看...
# 20      13561               千里迢迢从异国他乡买了个中国产的，且包装太简单，杯子都脏了，建议去某东买
# 21       3312  质量一般般。买来约2个月，测了20次左右。开始几次测的血糖值是4.7-9.7。2017-1-...
# 22      18266  这锅确实够扎实，如果有这种款式而又有20cm直径的话会更好。这锅不是很大的那种哦，煮一锅汤也...
# 23      14770                                   什么都好就是送货速度跟不上！慢慢
# 24      14883                                质量太差，还没用几天就发现一个键是坏的
# 25      19068                                         一般般，不是很满意。
# 26       9813              手工皂收到了，很不错，味道很舒服，清洁度效果不错，保湿，卖家人很好，很满意
# 27      15442                                   包装好旧的感觉。像是被用过了的。
# 28      14436        收到后没发现什么不对的地方,洗洗晒晒之后就直接用了.本人感觉各方面都不错.这个价格值了
# 29      19304           拳套太大了，还有大拇指太受力了，带着打了两天大拇指那肉都疼，还不如送的绷带实际。
# ...       ...                                                ...
# 15856    3836                              ?包装好随意 保湿也感觉不到 反正没下次了
# 15857    3261                                     智能能没什么用跟普通没啥差别
# 15858    3660                   保暖衣还好。和商家苗述一样。很满意。以后还买你家！&lsquo;
# 15859     749                           很满意的一次购物，快递小哥也很不错一直帮我送到家
# 15860   13416                             很柔，吸水性好。如果能再宽10cm就更好啦！
# 15861   11073          不想说，准备下手购买的请看清楚吧，好明显不是人为，是质量问题。难道先锋没有检测员？
# 15862   16705     不要轻信网上的宣传了，刚开始还可以，但是用了几次之后觉得刺激，用了之后皮肤粗糙，尤其是T区。
# 15863    7372                                         一般吧，没什么特殊的
# 15864   12427                      虽然在保质期可用，但我是冲“全新品”来的，不免有些失望了。
# 15865    2271                                      太干了；皮肤都感觉没喝到水
# 15866   19728  1、质料相当不好，人造木板，很重，但绝不耐用那种； 2、安装麻烦，中午三点左右到的货，一直奋...
# 15867   15763                                      还不错，保温比宜家的好得多
# 15868   14062                   很小，自己放几片小圆饼干，但小孙子外出给他食用。大概只能放3片。
# 15869    7656                             手感不错，就是两边太厚了，装上后按键都碰不到
# 15870    3175                                        使用时间不长，不是很好
# 15871    8001  **商家，缺德商家，你不想给赠品，可以直说，没必要这么忽悠消费者，大家不要在他家买东西了，买...
# 15872     852                 发货速度也很快，第三天就收到了。服务态度也很好，下次还考虑来[追评]
# 15873    4566                                        都挺好的，除了价格以外
# 15874    5088                                     不错，这个价钱买到的，好评。
# 15875    6620                                 给亲戚卖的一直支持华为，希望能用的住
# 15876     708  产地上海，跟图片一致。因为我皮肤是属于难吸收的，所以我一般敷半小时，揭下来后皮肤挺水润，第二...
# 15877   10983  板子有损，与客服联系，说补发要年后，可那时订单早过时间，我不同意。又说可以赔偿20元，但要下...
# 15878    6977                     是小天鹅售后的师傅过来给安装的，工作非常认真热情，洗衣机超赞
# 15879   10523            坏了一瓶，换来换去麻烦，就不换了，其他还可以，就是2017年就过期了，感觉不好
# 15880    2528                                ，什么破玩意那么小，根本就不值这个价钱
# 15881    7950                                        不错，很喜欢，发货很快
# 15882    8170                                        不推荐，很干。不会再买
# 15883   11630                               跟第一次买的不一样，颜色很淡，也不是撕拉
# 15884    7963                         可以，但是感觉有点贵&hellip;&hellip;
# 15885   10001                                  很满意，价钱不贵，国产电视海信最好
#
#                                      theme                 sentiment_word  \
# 0                                    NULL;                            满意;
# 1                              牙刷;NULL;觉得;                     粗糙;差;不是正品;
# 2                               NULL;NULL;                         正品;好用;
# 3                                   声音;电池;                      还可以;不怎么样;
# 4                          NULL;NULL;NULL;                      好看;实用;喜欢;
# 5                                 感觉;NULL;                           坑;坑;
# 6                                  屈臣氏;手霜;                          好用;好;
# 7                                   味道;效果;                      不是很好;没明显;
# 8                                      内衣;                            太薄;
# 9                             感觉;NULL;支撑力;                       不错;假;挺好;
# 10                                   NULL;                           还可以;
# 11                          产品;NULL;购买;设计;                不入流;没有糊弄;正品;缺乏;
# 12                                     感觉;                            不少;
# 13                           眼睛;NULL;NULL;                       痒;标准;不行;
# 14                                   NULL;                            合适;
# 15                                   NULL;                            不牢;
# 16                                      货;                             快;
# 17                                   NULL;                            好评;
# 18                          样子;NULL;网购;价格;                  还可以;不值;失败;太高;
# 19                                     喷雾;                             坏;
# 20                                  包装;杯子;                          简单;脏;
# 21                                     质量;                           一般般;
# 22                                 锅;款式;锅;                    不是很大;更好;扎实;
# 23                                   送货速度;                             好;
# 24                                   键;质量;                          坏;太差;
# 25                              NULL;NULL;                      不是满意;一般般;
# 26                     效果;味道;NULL;NULL;卖家;                不错;舒服;不错;满意;很好;
# 27                             NULL;包装;感觉;                       被用过;好;旧;
# 28                               各方面;NULL;                        不错;没不对;
# 29                                      肉;                             疼;
# ...                                    ...                            ...
# 15856                        NULL;包装;NULL;                        次;好;随意;
# 15857                             差别;NULL;                      没什么普通;智能;
# 15858                            保暖衣;NULL;                         还好;满意;
# 15859                             购物;快递小哥;                         满意;不错;
# 15860                            NULL;吸水性;                          更好;好;
# 15861                                NULL;                          不是明显;
# 15862                             皮肤;NULL;                        粗糙;还可以;
# 15863                                NULL;                            一般;
# 15864                                NULL;                            失望;
# 15865                                NULL;                             干;
# 15866  NULL;质料;NULL;NULL;长度;挡板;安装;NULL;网购;  没好;不好;卓越;很重;不标准;薄;麻烦;绝不耐用;后悔;
# 15867                                NULL;                            不错;
# 15868                                NULL;                            很小;
# 15869                             手感;NULL;                          不错;厚;
# 15870                                NULL;                          不是很好;
# 15871                NULL;NULL;商家;手机;NULL;              没忽悠;可以;缺德;热情;有问题;
# 15872                           发货速度;服务态度;                         很快;很好;
# 15873                                NULL;                            挺好;
# 15874                           NULL;NULL;                         不错;好评;
# 15875                                NULL;                            能用;
# 15876               皮肤;NULL;NULL;皮肤;肌肤;图片;             难吸;洁面;一般;水润;不错;一致;
# 15877                           NULL;NULL;                         可以;长久;
# 15878                         洗衣机;工作;NULL;                      超赞;认真;热情;
# 15879              NULL;NULL;NULL;感觉;NULL;                麻烦;过期;坏;不好;还可以;
# 15880                             价钱;NULL;                          不值;破;
# 15881                        发货;NULL;NULL;                      很快;不错;喜欢;
# 15882                           NULL;NULL;                        不推荐;很干;
# 15883                                  颜色;                            很淡;
# 15884                             感觉;NULL;                          贵;可以;
# 15885                          海信;价钱;NULL;                      最好;不贵;满意;
#
#                  sentiment_anls
# 0                            1;
# 1                     -1;-1;-1;
# 2                          1;1;
# 3                         1;-1;
# 4                        1;1;1;
# 5                        -1;-1;
# 6                          1;1;
# 7                         -1;0;
# 8                            0;
# 9                       1;-1;1;
# 10                           1;
# 11                   -1;1;1;-1;
# 12                           1;
# 13                     -1;0;-1;
# 14                           1;
# 15                          -1;
# 16                           1;
# 17                           1;
# 18                  1;-1;-1;-1;
# 19                          -1;
# 20                        1;-1;
# 21                           0;
# 22                      -1;1;1;
# 23                           1;
# 24                       -1;-1;
# 25                        -1;0;
# 26                   1;1;1;1;1;
# 27                     -1;1;-1;
# 28                         1;1;
# 29                          -1;
# ...                         ...
# 15856                   -1;1;1;
# 15857                      0;1;
# 15858                      1;1;
# 15859                      1;1;
# 15860                      1;1;
# 15861                        0;
# 15862                     -1;1;
# 15863                        0;
# 15864                       -1;
# 15865                       -1;
# 15866  -1;-1;1;-1;0;0;-1;-1;-1;
# 15867                        1;
# 15868                        1;
# 15869                      1;0;
# 15870                       -1;
# 15871              1;1;-1;1;-1;
# 15872                      1;1;
# 15873                        1;
# 15874                      1;1;
# 15875                        1;
# 15876             -1;1;0;1;1;1;
# 15877                      1;1;
# 15878                    1;1;1;
# 15879            -1;-1;-1;-1;1;
# 15880                    -1;-1;
# 15881                    1;1;1;
# 15882                    -1;-1;
# 15883                       -1;
# 15884                     -1;1;
# 15885                    1;1;1;
#
# [15886 rows x 5 columns]

# %%
row = data.iloc[22]

# %%
row
# Out:
# row_id                                                        18266
# content           这锅确实够扎实，如果有这种款式而又有20cm直径的话会更好。这锅不是很大的那种哦，煮一锅汤也...
# theme                                                       锅;款式;锅;
# sentiment_word                                          不是很大;更好;扎实;
# sentiment_anls                                              -1;1;1;
# Name: 22, dtype: object

# %%
xx = row["content"]

# %%
xx
# Out:
# '这锅确实够扎实，如果有这种款式而又有20cm直径的话会更好。这锅不是很大的那种哦，煮一锅汤也就够三个人吃。'

# %%
import re
def tagging(content, words):
    index_dict = {}
    word_list = words.split(';')
    for word in word_list:
        if word != "NULL" and word != "":
            location = [m.start() for m in re.finditer(word, content)]
            for pos in location:
                index_dict[pos] = len(word)
        else:
            pass
    keys = list(index_dict.keys())
    keys = sorted(keys)
    pos = 0
    end = len(content) - 1
    i = 0
    res = []
    while(i <= end):
        if pos >= len(keys) or i != keys[pos]:
            res.append(content[i] + "/N")
            i = i + 1
        else:
            length = index_dict[keys[pos]]
            if length == 1:
                res.append(content[i] + "/S")
            else:
                for j in range(length):
                    if j == 0:
                        res.append(content[i + j] + "/B")
                    elif j == length - 1:
                        res.append(content[i + j] + "/E")
                    else:
                        res.append(content[i + j] + "/M")
            i = i + length
            pos = pos + 1
    s = res[0]
    for i in range(1, len(res)):
        s = s + ' ' + res[i]
    s = s + '\n'
    return s

for index, row in data.iterrows():
    with open('./data/sentiment_word_tagging_train.csv', 'a') as f:
        res = tagging(row["content"], row["sentiment_word"])
        f.write(res)
