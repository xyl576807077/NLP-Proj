# %%
import pandas as pd
import numpy as np
raw_data = pd.read_csv('./data/sentiment_word_tagging_train.csv', header=None, delimiter='\t')
str(raw_data.iloc[0].values[0])
# Out:
# '给/N 妈/N 妈/N 买/N 的/N ，/N 妈/N 妈/N 很/N 满/B 意/E 。/N'

# %%
s = ''
for index, row in raw_data.iterrows():
    if index != 0:
        s = s + ' '
    s = s + row.values[0]

# %%
import re
import tqdm
sentences = re.split(u'[，。！？、‘’“”]/[BMENS]', s)

def get_Xy(sentence):
    """将 sentence 处理成 [word1, w2, ..wn], [tag1, t2, ...tn]"""
    words_tags = re.findall('(.)/(.)', sentence)
    if words_tags:
        words_tags = np.asarray(words_tags)
        words = words_tags[:, 0]
        tags = words_tags[:, 1]
        return words, tags # 所有的字和tag分别存为 data / label
    return None

datas = []
labels = []
for sentence in iter(sentences):
    res = get_Xy(sentence)
    if res:
        datas.append(res[0])
        labels.append(res[1])

# %%
df_data = pd.DataFrame({'words': datas, 'tags': labels}, index=range(len(datas)))
#　句子长度
df_data['sentence_len'] = df_data['words'].apply(lambda words: len(words))
df_data.head(2)
# Out:
#               tags            words  sentence_len
# 0  [N, N, N, N, N]  [给, 妈, 妈, 买, 的]             5
# 1  [N, N, N, B, E]  [妈, 妈, 很, 满, 意]             5

# %%
import matplotlib.pyplot as plt
df_data['sentence_len'].hist(bins=100)
plt.xlim(0, 100)
plt.xlabel('sentence_length')
plt.ylabel('sentence_num')
plt.title('Distribution of the Length of Sentence')
plt.show()

# %%
from itertools import chain
all_words = list(chain(*df_data['words'].values))

# %%
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
word_index = tokenizer.fit_on_texts(all_words)

# %%
from keras.preprocessing.sequence import pad_sequences
df_data['X'] = df_data['words'].apply(pad_sequences)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-ff1f43a4df68> in <module>()
#       1 from keras.preprocessing.sequence import pad_sequences
# ----> 2 df_data['X'] = df_data['words'].apply(pad_sequences)
#
# ~/anaconda2/envs/xixi/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer (pandas/_libs/lib.c:66645)()
#
# ~/anaconda2/envs/xixi/lib/python3.5/site-packages/keras/preprocessing/sequence.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#      67
#      68         # check `trunc` has expected shape
# ---> 69         trunc = np.asarray(trunc, dtype=dtype)
#      70         if trunc.shape[1:] != sample_shape:
#      71             raise ValueError('Shape of sample %s of sequence at position %s is different from expected shape %s' %
#
# ~/anaconda2/envs/xixi/lib/python3.5/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     529
#     530     """
# --> 531     return array(a, dtype, copy=False, order=order)
#     532
#     533
#
# ValueError: invalid literal for int() with base 10: '给'

# %%
df_data
# Out:
#                                                     tags  \
# 0                                        [N, N, N, N, N]
# 1                                        [N, N, N, B, E]
# 2                                  [N, N, N, B, M, M, E]
# 3                   [N, N, N, N, N, N, N, N, N, N, B, E]
# 4                                              [N, N, N]
# 5                                  [N, N, N, N, S, N, N]
# 6      [N, N, N, N, N, N, N, N, N, N, N, N, N, N, N, ...
# 7                   [N, N, N, N, N, N, N, N, N, N, N, N]
# 8             [N, N, N, N, N, N, N, N, N, N, N, N, N, N]
# 9      [N, N, N, N, N, N, S, N, N, N, N, B, E, N, N, ...
# 10                        [N, N, B, M, M, E, N, N, B, E]
# 11                                                [B, E]
# 12     [B, E, N, N, N, S, N, N, N, N, N, N, N, N, N, ...
# 13     [N, N, N, N, N, N, N, N, N, N, N, N, N, N, S, ...
# 14     [N, N, N, N, N, N, B, E, N, N, N, N, N, N, N, ...
# 15                                          [N, N, B, E]
# 16                                    [N, N, N, B, E, N]
# 17                           [N, N, N, N, N, N, N, N, N]
# 18      [N, N, N, N, N, N, N, N, N, N, N, N, N, N, N, N]
# 19     [N, N, N, N, N, N, N, N, N, S, N, N, N, N, N, ...
# 20     [B, M, E, N, N, N, N, N, N, N, N, N, N, N, N, ...
# 21                                          [N, N, N, N]
# 22                              [N, N, N, N, N, N, N, N]
# 23            [N, N, N, N, N, N, N, N, N, N, N, N, N, N]
# 24                           [N, N, N, N, B, E, N, N, N]
# 25                              [N, N, N, N, N, N, N, N]
# 26     [N, N, N, N, N, N, N, N, B, E, N, N, N, B, M, ...
# 27                              [N, N, N, N, N, N, N, N]
# 28                                       [N, N, N, N, N]
# 29                                          [N, N, N, N]
# ...                                                  ...
# 50766                                       [N, N, N, N]
# 50767                                    [N, N, N, N, N]
# 50768                                 [N, N, N, N, N, N]
# 50769                        [N, N, N, N, N, N, N, N, N]
# 50770                                       [N, N, N, N]
# 50771                        [N, N, B, E, N, N, N, N, N]
# 50772                           [N, N, N, N, N, N, N, N]
# 50773                                    [N, N, N, N, N]
# 50774                  [N, N, N, N, N, N, N, N, N, N, N]
# 50775                                             [N, N]
# 50776                        [N, N, N, N, N, N, N, B, E]
# 50777      [N, N, N, N, N, N, N, N, N, N, N, N, N, N, N]
# 50778                           [N, N, N, N, B, E, B, E]
# 50779                        [N, N, N, B, E, S, N, N, N]
# 50780                                 [N, N, N, N, B, E]
# 50781                                       [N, N, N, N]
# 50782                                    [N, N, B, M, E]
# 50783                  [N, N, N, N, N, N, N, N, B, E, N]
# 50784                                       [N, N, B, E]
# 50785                           [N, N, S, N, N, N, N, N]
# 50786                  [N, N, N, B, E, N, N, N, N, B, E]
# 50787                                          [N, B, E]
# 50788                              [N, N, B, E, B, M, E]
# 50789                                             [B, E]
# 50790            [N, N, N, N, N, N, N, N, N, N, N, N, N]
# 50791                                       [N, N, B, E]
# 50792                              [N, N, N, N, N, B, E]
# 50793  [N, N, N, N, N, N, S, N, N, N, N, N, N, N, N, ...
# 50794                                       [N, N, B, E]
# 50795                           [N, N, N, N, N, N, B, E]
#
#                                                    words  sentence_len
# 0                                        [给, 妈, 妈, 买, 的]             5
# 1                                        [妈, 妈, 很, 满, 意]             5
# 2                                  [我, 觉, 得, 不, 是, 正, 品]             7
# 3                   [牙, 刷, 的, 后, 面, 有, 个, 点, 非, 常, 粗, 糙]            12
# 4                                              [刮, 嘴, 唇]             3
# 5                                  [和, 原, 厂, 的, 差, 太, 远]             7
# 6      [之, 前, 用, 的, 刷, 头, 上, 写, 的, 是, d, i, a, m, o, ...            23
# 7                   [这, 个, 是, s, o, n, i, c, c, a, r, e]            12
# 8             [当, 然, 不, 排, 除, 改, 版, 质, 量, 下, 降, 的, 因, 素]            14
# 9      [但, 和, 以, 前, 买, 的, 差, 太, 多, 了, 是, 正, 品,  ,  , ...            28
# 10                        [电, 池, 不, 怎, 么, 样, 家, 人, 喜, 欢]            10
# 11                                                [好, 看]             2
# 12     [实, 用, 感, 觉, 被, 坑, 了, &, h, e, l, l, i, p, ;, ...            74
# 13     [还, 不, 及, 我, 1, 0, 块, 钱, 一, 支, 的, 屈, 臣, 氏, 好, ...            22
# 14     [效, 果, 没, 多, 明, 显, 太, 薄, 了, 根, 本, 不, 是, 保, 暧, ...            31
# 15                                          [感, 觉, 不, 错]             4
# 16                                    [支, 撑, 力, 挺, 好, 的]             6
# 17                           [不, 知, 是, 否, 和, 体, 重, 有, 关]             9
# 18      [但, 这, 床, 垫, 沒, 有, 之, 前, 购, 买, 乳, 胶, 枕, 的, 味, 道]            16
# 19     [也, 不, 知, 道, 是, 真, 货, 还, 是, 假, 的, 活, 动, 时, 购, ...            17
# 20     [还, 可, 以, 吧, 这, 是, R, a, i, n,  , D, e, s, i, ...            29
# 21                                          [百, 度, 一, 下]             4
# 22                              [一, 看, 设, 计, 雅, 俗, 立, 分]             8
# 23            [明, 显, 是, 糊, 弄, 没, 有, 品, 位, 的, 冤, 大, 头, 呢]            14
# 24                           [价, 格, 购, 买, 正, 品, 两, 个, 了]             9
# 25                              [ , 且, 不, 管, 是, 否, 模, 仿]             8
# 26     [但, 看, 外, 观, 设, 计, 就, 是, 缺, 乏, 品, 位, 的, 不, 入, ...            18
# 27                              [画, 虎, 不, 成, 反, 类, 犬, 了]             8
# 28                                       [没, 赶, 上, 特, 价]             5
# 29                                          [但, 有, 需, 求]             4
# ...                                                  ...           ...
# 50766                                       [板, 子, 有, 损]             4
# 50767                                    [与, 客, 服, 联, 系]             5
# 50768                                 [说, 补, 发, 要, 年, 后]             6
# 50769                        [可, 那, 时, 订, 单, 早, 过, 时, 间]             9
# 50770                                       [我, 不, 同, 意]             4
# 50771                        [又, 说, 可, 以, 赔, 偿, 2, 0, 元]             9
# 50772                           [但, 要, 下, 周, 才, 能, 办, 理]             8
# 50773                                    [半, 个, 月, 过, 去]             5
# 50774                  [找, 各, 种, 理, 由, 一, 直, 拖, 着, 不, 办]            11
# 50775                                             [呵, 呵]             2
# 50776                        [这, 样, 的, 商, 家, 能, 做, 长, 久]             9
# 50777      [是, 小, 天, 鹅, 售, 后, 的, 师, 傅, 过, 来, 给, 安, 装, 的]            15
# 50778                           [工, 作, 非, 常, 认, 真, 热, 情]             8
# 50779                        [洗, 衣, 机, 超, 赞, 坏, 了, 一, 瓶]             9
# 50780                                 [换, 来, 换, 去, 麻, 烦]             6
# 50781                                       [就, 不, 换, 了]             4
# 50782                                    [其, 他, 还, 可, 以]             5
# 50783                  [就, 是, 2, 0, 1, 7, 年, 就, 过, 期, 了]            11
# 50784                                       [感, 觉, 不, 好]             4
# 50785                           [什, 么, 破, 玩, 意, 那, 么, 小]             8
# 50786                  [根, 本, 就, 不, 值, 这, 个, 价, 钱, 不, 错]            11
# 50787                                          [很, 喜, 欢]             3
# 50788                              [发, 货, 很, 快, 不, 推, 荐]             7
# 50789                                             [很, 干]             2
# 50790            [不, 会, 再, 买, 跟, 第, 一, 次, 买, 的, 不, 一, 样]            13
# 50791                                       [颜, 色, 很, 淡]             4
# 50792                              [也, 不, 是, 撕, 拉, 可, 以]             7
# 50793  [但, 是, 感, 觉, 有, 点, 贵, &, h, e, l, l, i, p, ;, ...            26
# 50794                                       [价, 钱, 不, 贵]             4
# 50795                           [国, 产, 电, 视, 海, 信, 最, 好]             8
#
# [50796 rows x 3 columns]
