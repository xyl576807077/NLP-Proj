# %%
#从train.csv中，读取情感词
import pandas as pd
import numpy as np

raw_data = pd.read_csv('./train.csv', delimiter='\t')
sentiment = raw_data['sentiment_word']

#从segmentor_result
raw = pd.read_csv('./segmentor_result.csv', delimiter='\t', header=None, error_bad_lines=False)
# sentiment = raw_data[0]
raw
# Out:
# b'Skipping line 2: expected 9 fields, saw 54\nSkipping line 6: expected 9 fields, saw 29\nSkipping line 7: expected 9 fields, saw 20\nSkipping line 8: expected 9 fields, saw 10\nSkipping line 9: expected 9 fields, saw 10\nSkipping line 10: expected 9 fields, saw 40\nSkipping line 12: expected 9 fields, saw 57\nSkipping line 13: expected 9 fields, saw 20\nSkipping line 14: expected 9 fields, saw 27\nSkipping line 17: expected 9 fields, saw 17\nSkipping line 18: expected 9 fields, saw 10\nSkipping line 19: expected 9 fields, saw 77\nSkipping line 20: expected 9 fields, saw 42\nSkipping line 21: expected 9 fields, saw 25\nSkipping line 22: expected 9 fields, saw 50\nSkipping line 23: expected 9 fields, saw 42\nSkipping line 25: expected 9 fields, saw 14\nSkipping line 27: expected 9 fields, saw 24\nSkipping line 28: expected 9 fields, saw 11\nSkipping line 30: expected 9 fields, saw 30\nSkipping line 31: expected 9 fields, saw 176\nSkipping line 32: expected 9 fields, saw 29\nSkipping l
# ...
